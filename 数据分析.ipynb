# %%
import os,json

# %%
with open('./code/ours_normal.json','r')as f:
    data1 = json.load(f)
with open('./code/zs_normal.json','r')as f1:
    data2 = json.load(f1)
    
    
for key,value in data1.items():
    if value[1] == value[2][0] and data2[key][1] !=data2[key][2][0]:
        print(key,value,'\n',data2[key])
# Out:
# 1240 [1240, 'baseball', ['baseball', 'tennis ball', 'wii', 'volleyball', 'baseball bat', 'baseball glove', 'play baseball', 'baseball field', 'frisbee', 'racket'], ['belong to', 'related to', 'used for', 'is a', 'part of', 'at location', 'capable of', 'receives action', 'has property', 'has a', 'created by', 'desires', 'warm', 'cool', 'sweet'], ['baseball game', 'tennis game', 'video game', 'ball games', 'baseball field', 'sport game', 'team game', 'hit baseball', 'game', 'golf club', 'winter olympic games', 'olympic games', 'tennis ball', 'competitive games', 'football'], ['hit baseball-used for', 'sport game-is a', 'baseball game-at location', 'tennis game-at location', 'hit baseball-capable of', 'ball games-belong to', 'competitive games-belong to', 'baseball field-at location', 'baseball field-used for', 'game-is a', 'video game-belong to'], ['volleyball', 'play baseball', 'wii', 'baseball bat', 'baseball', 'racket', 'frisbee', 'tennis ball']]
# ...

# %%
with open('./code/ours_data_normal.json','r')as f:
    data = json.load(f)

with open('./code/test.json','w')as f:
    json.dump(data, f, sort_keys=True, indent=4, separators=(',', ':'), ensure_ascii=False)
